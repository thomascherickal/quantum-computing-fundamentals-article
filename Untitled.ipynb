# %%
# Import necessary components
import matplotlib
# Set the backend BEFORE importing qiskit.visualization
matplotlib.use('GTK3Agg') # Or 'Qt5Agg', 'GTK3Agg', etc.

from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_bloch_multivector


# Create a circuit with one qubit
qc = QuantumCircuit(1)

# --- Step 1: Create Superposition ---
# Apply a Hadamard gate to put the qubit in the state (|0> + |1>)/sqrt(2)
qc.h(0)

# Get the statevector and visualize on the Bloch sphere
state_after_h = Statevector(qc)
print("State after Hadamard gate:")
print(state_after_h.draw('text'))
plot_bloch_multivector(state_after_h, title="After H-gate").show()

# --- Step 2: Manipulate Superposition ---
# Apply a Z-gate, which flips the phase of the |1> component.
# The state becomes (|0> - |1>)/sqrt(2)codePython
qc.z(0)

# Get the new statevector and visualize
state_after_z = Statevector(qc)
print("\nState after Z-gate:")
print(state_after_z.draw('text'))
print(qc)
plot_bloch_multivector(state_after_z, title="After Z-gate").show()
# Out:
# State after Hadamard gate:
# [0.70710678+0.j,0.70710678+0.j]
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/Tools/Anaconda/lib/python3.13/site-packages/matplotlib/backends/backend_gtk3.py:13
#      12 try:
# ---> 13     import gi
#      14 except ImportError as err:
#
# ModuleNotFoundError: No module named 'gi'
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 22
#      20 print("State after Hadamard gate:")
#      21 print(state_after_h.draw('text'))
# ---> 22 plot_bloch_multivector(state_after_h, title="After H-gate").show()
#      24 # --- Step 2: Manipulate Superposition ---
#      25 # Apply a Z-gate, which flips the phase of the |1> component.
#      26 # The state becomes (|0> - |1>)/sqrt(2)codePython
#      27 qc.z(0)
#
# File ~/Tools/Anaconda/lib/python3.13/site-packages/qiskit/utils/lazy_tester.py:165, in LazyDependencyManager.require_in_call.<locals>.out(*args, **kwargs)
#     162 @functools.wraps(function)
#     163 def out(*args, **kwargs):
#     164     self.require_now(feature)
# --> 165     return function(*args, **kwargs)
#
# File ~/Tools/Anaconda/lib/python3.13/site-packages/qiskit/visualization/state_visualization.py:353, in plot_bloch_multivector(state, title, figsize, reverse_bits, filename, font_size, title_font_size, title_pad)
#     351 default_title_font_size = font_size if font_size is not None else 16
#     352 title_font_size = title_font_size if title_font_size is not None else default_title_font_size
# --> 353 fig = plt.figure(figsize=(width, height))
#     354 for i in range(num):
#     355     pos = num - 1 - i if reverse_bits else i
#
# File ~/Tools/Anaconda/lib/python3.13/site-packages/matplotlib/pyplot.py:1042, in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#    1032 if len(allnums) == max_open_warning >= 1:
#    1033     _api.warn_external(
#    1034         f"More than {max_open_warning} figures have been opened. "
#    1035         f"Figures created through the pyplot interface "
#    (...)
#    1039         f"Consider using `matplotlib.pyplot.close()`.",
#    1040         RuntimeWarning)
# -> 1042 manager = new_figure_manager(
#    1043     num, figsize=figsize, dpi=dpi,
#    1044     facecolor=facecolor, edgecolor=edgecolor, frameon=frameon,
#    1045     FigureClass=FigureClass, **kwargs)
#    1046 fig = manager.canvas.figure
#    1047 if fig_label:
#
# File ~/Tools/Anaconda/lib/python3.13/site-packages/matplotlib/pyplot.py:551, in new_figure_manager(*args, **kwargs)
#     549 def new_figure_manager(*args, **kwargs):
#     550     """Create a new figure manager instance."""
# --> 551     _warn_if_gui_out_of_main_thread()
#     552     return _get_backend_mod().new_figure_manager(*args, **kwargs)
#
# File ~/Tools/Anaconda/lib/python3.13/site-packages/matplotlib/pyplot.py:528, in _warn_if_gui_out_of_main_thread()
#     526 def _warn_if_gui_out_of_main_thread() -> None:
#     527     warn = False
# --> 528     canvas_class = cast(type[FigureCanvasBase], _get_backend_mod().FigureCanvas)
#     529     if canvas_class.required_interactive_framework:
#     530         if hasattr(threading, 'get_native_id'):
#     531             # This compares native thread ids because even if Python-level
#     532             # Thread objects match, the underlying OS thread (which is what
#     533             # really matters) may be different on Python implementations with
#     534             # green threads.
#
# File ~/Tools/Anaconda/lib/python3.13/site-packages/matplotlib/pyplot.py:369, in _get_backend_mod()
#     360 """
#     361 Ensure that a backend is selected and return it.
#     362
#     363 This is currently private, but may be made public in the future.
#     364 """
#     365 if _backend_mod is None:
#     366     # Use rcParams._get("backend") to avoid going through the fallback
#     367     # logic (which will (re)import pyplot and then call switch_backend if
#     368     # we need to resolve the auto sentinel)
# --> 369     switch_backend(rcParams._get("backend"))
#     370 return cast(type[matplotlib.backend_bases._Backend], _backend_mod)
#
# File ~/Tools/Anaconda/lib/python3.13/site-packages/matplotlib/pyplot.py:425, in switch_backend(newbackend)
#     422         return
#     423 old_backend = rcParams._get('backend')  # get without triggering backend resolution
# --> 425 module = backend_registry.load_backend_module(newbackend)
#     426 canvas_class = module.FigureCanvas
#     428 required_framework = canvas_class.required_interactive_framework
#
# File ~/Tools/Anaconda/lib/python3.13/site-packages/matplotlib/backends/registry.py:317, in BackendRegistry.load_backend_module(self, backend)
#     303 """
#     304 Load and return the module containing the specified backend.
#     305
#    (...)
#     314     Module containing backend.
#     315 """
#     316 module_name = self._backend_module_name(backend)
# --> 317 return importlib.import_module(module_name)
#
# File ~/Tools/Anaconda/lib/python3.13/importlib/__init__.py:88, in import_module(name, package)
#      86             break
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1331, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:935, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:1026, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:488, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/Tools/Anaconda/lib/python3.13/site-packages/matplotlib/backends/backend_gtk3agg.py:4
#       1 import numpy as np
#       3 from .. import cbook, transforms
# ----> 4 from . import backend_agg, backend_gtk3
#       5 from .backend_gtk3 import GLib, Gtk, _BackendGTK3
#       7 import cairo  # Presence of cairo is already checked by _backend_gtk.
#
# File ~/Tools/Anaconda/lib/python3.13/site-packages/matplotlib/backends/backend_gtk3.py:15
#      13     import gi
#      14 except ImportError as err:
# ---> 15     raise ImportError("The GTK3 backends require PyGObject") from err
#      17 try:
#      18     # :raises ValueError: If module/version is already loaded, already
#      19     # required, or unavailable.
#      20     gi.require_version("Gtk", "3.0")
#
# ImportError: The GTK3 backends require PyGObject
